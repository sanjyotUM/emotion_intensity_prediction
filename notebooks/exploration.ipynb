# %%
import pandas as pd

pd.set_option('max_colwidth', 500)

# %%
train_path = '../datasets/emotion_detection_semeval2017/combined/train.csv'

# %%
train = pd.read_csv(train_path)

# %%
train.sample(frac=1).head(20)
# Out:
#          id  \
# 1955  30312
# 3393  20927
# 1129  40272
# 1475  40618
# 3748  40837
# 3732  40821
# 1162  40305
# 679   10679
# 1824  30181
# 2052  30409
# 1053  40196
# 843   10843
# 3379  20913
# 42    10042
# 1490  40633
# 2420  30777
# 3486  21020
# 2397  30754
# 40    10040
# 2814  20348
#
#                                                                                                                                           tweet  \
# 1955                                                                                                               @bradshawjp Sweet! #optimism
# 3393                                                                                                                  To com sede de milk shake
# 1129                     From what I know of the man, I have to assume that @realDonaldTrump has had a heated argument with his own penis. #sad
# ...

# %% [markdown]
# ## Ideas
#
# #### Preprocess
# 1. Emoji extraction and replacement with equivalent English word
# 1. Hashtag extraction
# 1. Tweet handle extraction
#
#
# ### Features
